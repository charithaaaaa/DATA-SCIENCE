# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings as wr
wr.filterwarnings('ignore')
df=pd.read_csv('insurence.csv')
df
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
df.describe()
# Out:
#                age          bmi     children      expenses
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.665471     1.094918  13270.422414
# std      14.049960     6.098382     1.205493  12110.011240
# min      18.000000    16.000000     0.000000   1121.870000
# 25%      27.000000    26.300000     0.000000   4740.287500
# 50%      39.000000    30.400000     1.000000   9382.030000
# 75%      51.000000    34.700000     2.000000  16639.915000
# max      64.000000    53.100000     5.000000  63770.430000

# %%
df.shape
# Out:
# (1338, 7)

# %%
print(df.age.nunique())
print(df.sex.nunique())
print(df.bmi.nunique())
print(df.children.nunique())
print(df.smoker.nunique())
print(df.region.nunique())
print(df.expenses.nunique())
# Out:
# 47
# 2
# 275
# 6
# 2
# 4
# 1337

# %%
print(df.age.isnull().sum())
print(df.sex.isnull().sum())
print(df.bmi.isnull().sum())
print(df.children.isnull().sum())
print(df.smoker.isnull().sum())
print(df.region.isnull().sum())
print(df.expenses.isnull().sum())
# Out:
# 0
# 0
# 0
# 0
# 0
# 0
# 0

# %% [markdown]
# UNI VARIENT

# %%
df['expenses'].describe()
# Out:
# count     1338.000000
# mean     13270.422414
# std      12110.011240
# min       1121.870000
# 25%       4740.287500
# 50%       9382.030000
# 75%      16639.915000
# max      63770.430000
# Name: expenses, dtype: float64

# %%
from scipy.stats import skew, kurtosis# scipy package is package for stats
print(skew(df.expenses, bias=False))
print(kurtosis(df.expenses,bias=False))
# Out:
# 1.5158796628979796
# 1.6062986577747607

# %%
sns.boxplot(df.expenses)
# Out:
# <Axes: >

# %%
sns.countplot(df,x="sex")
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(df,x="children")
# Out:
# <Axes: xlabel='children', ylabel='count'>

# %% [markdown]
# # Bi-Varient Analysis

# %%
sns.barplot(x='sex',y='expenses',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='expenses'>

# %%
sns.barplot(x='age',y='region',data=df)
# Out:
# <Axes: xlabel='age', ylabel='region'>

# %%
sns.jointplot(data=df,x='expenses',y='sex')

# %%
sns.barplot(x='age',y='expenses',data=df)
# Out:
# <Axes: xlabel='age', ylabel='expenses'>

# %%
sns.jointplot(data=df,x='age',y='expenses',hue="sex")

# %%
sns.boxplot(x='smoker',y='expenses',data=df,palette='rainbow')
# Out:
# <Axes: xlabel='smoker', ylabel='expenses'>

# %%
sns.violinplot(x="sex",y="expenses",data=df,palette='rainbow')
# Out:
# <Axes: xlabel='sex', ylabel='expenses'>

# %% [markdown]
# In case we have large datasets with 30-70+ features (variables), there might not be sufficient time to run each pair of varience through bivarient analysis one by one.

# %%
sns.pairplot(df,hue="sex")

# %%
sns.pairplot(df,hue="age")
